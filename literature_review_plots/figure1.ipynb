# %%
"""
Set up the figure 1 plot: General trends across the brain of autapse formation

4 panels:
    - region/layer specificity
    - projection specificity
    - neuron-type specificity
    * final: autapse occurence throughtout the brain.

"""

# %%
import numpy as np
import pandas as pd

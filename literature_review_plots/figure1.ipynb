# %%
"""
Figure 1 overview: general trends in autapse formation across the brain.

Planned panels:
    - region/layer specificity
    - projection specificity
    - neuron-type specificity
    - overall autapse occurrence throughout the brain
"""

# %%
# Numerical and tabular libraries used by the figure-planning notebook.
import numpy as np
import pandas as pd

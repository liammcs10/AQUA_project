# %%
'''
PLOT outputs from bursting_analysis.py


'''
import pickle
import pandas as pd

# %%
filename = "burst_analysis_testDIST.pickle"

with open(filename, 'rb') as file:
    df_dist = pickle.load(file)

print(df_dist.head())
# Out:
#      e           f  tau  I_inj   W  FT_distance     FT_EMD  ISI_distance  \
# 0  0.2    0.000000  2.0  200.0  56     1.976340  36.680473      0.003852
# 1  0.2  100.000000  2.0  200.0  56     1.874944  17.578809      0.005206
# 2  0.2  107.142857  2.0  200.0  56     2.509198  32.848061      0.005709
# 3  0.2  114.285714  2.0  200.0  56     2.823081  14.904314      0.006052
# 4  0.2  121.428571  2.0  200.0  56     2.919248  15.326825      0.006425
#
#    SPIKE_distance  SPIKE_synchrony  spike_directionality
# 0        0.086583              1.0             -0.987179
# 1        0.066336              1.0              0.987179
# 2        0.068703              1.0              0.987179
# 3        0.072621              1.0              0.987179
# 4        0.073093              1.0              0.987179

# %%
filename = "burst_analysis_testISI_E1.pickle"

with open(filename, 'rb') as file:
    df_isi = pickle.load(file)

print(df_isi.head())
# Out:
#    neuron_number    e           f  tau  I_inj   W  peak_isi       mean  \
# 0              0  0.2    0.000000  2.0    200  56     63.75  63.848684
# 1              1  0.2  100.000000  2.0    200  56     65.25  65.230000
# 2              2  0.2  107.142857  2.0    200  56     65.25  65.230000
# 3              3  0.2  114.285714  2.0    200  56     65.25  65.230000
# 4              4  0.2  121.428571  2.0    200  56     65.25  65.190000
#
#         std  count_sum    CV_isi        LV
# 0  0.371871         76  0.005824  0.001171
# 1  0.172047         75  0.002638  0.006253
# 2  0.172047         75  0.002638  0.006767
# 3  0.172047         75  0.002638  0.007290
# 4  0.382623         75  0.005869  0.007793

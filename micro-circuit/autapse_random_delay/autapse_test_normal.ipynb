# %%
import sys
sys.path.append("../")

from brian2 import *
import matplotlib.pyplot as plt
from tqdm import tqdm

from aqua.plotting_functions import *
from aqua.utils import *

from functions import *

# %%
"""- - - - MAIN SIMULATION - - - - """

T = 2000 # ms
N_trials = 100
N_spikes = 40
spike_delay = 4*ms

# normal distribution parameters
mean = 5*ms
std = 1*ms

counts = np.zeros(N_trials)

spike_delays = []

for i in tqdm(range(N_trials)):
    # 1. Setup Input (Presynaptic Neuron)
    # Let's say it fires at 20Hz
    #P = PoissonGroup(1, 20*Hz)
    idx = np.zeros(N_spikes)
    spike_times = np.linspace(10, 3*T/4, N_spikes)*ms
    ms_per_spike = (T/2 - 10)/N_spikes
    firing_frequency = 1000/ms_per_spike
    #print(f"FF: {firing_frequency}")
    P = SpikeGeneratorGroup(1, idx, spike_times)


    # 2. The Normal Generator Group
    NormGen = NeuronGroup(1, 
        '''
        scheduled_time : second
        is_active : boolean
        ''',
        threshold = 'is_active and t >= scheduled_time',
        reset = 'is_active = False',
        method = 'euler')

    # 3. Connect Pre-synapse to the Generator
    # Each spike from P increases the firing rate of PoissonGen
    S_in = Synapses(P, NormGen, on_pre='''
                    is_active = True
                    scheduled_time = t + (mean + randn()*std)
                    ''')
    S_in.connect()

    # 4. Connect Generator to Post-synaptic Target
    Post = NeuronGroup(1, 'dv/dt = -v/(10*ms) : 1', threshold='v>1', reset='v=0')
    S_out = Synapses(NormGen, Post, on_pre='v_post += 0.3')
    S_out.connect()


    # Monitors
    mon_p = SpikeMonitor(P)
    mon_gen = SpikeMonitor(NormGen)
    mon_post = StateMonitor(Post, 'v', record = True)
    spikemon_post = SpikeMonitor(Post, record = True)

    
    run(T*ms)


    spk_trn = mon_gen.spike_trains()[0]
    counts[i] = len(spk_trn)


    for spike in spk_trn:
        #print(spike)
        delay = spike - spike_times[spike_times < spike][-1]    #last spike before the poisson spike
        #print(delay)
        spike_delays.append(delay*1000)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]INFO       No numerical integration method specified for group 'neurongroup_3', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]
# WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   1%|          | 1/100 [00:05<08:56,  5.42s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   2%|▏         | 2/100 [00:07<06:02,  3.70s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   3%|▎         | 3/100 [00:10<05:03,  3.13s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   4%|▍         | 4/100 [00:12<04:33,  2.85s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   5%|▌         | 5/100 [00:15<04:16,  2.70s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   6%|▌         | 6/100 [00:16<03:14,  2.07s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   7%|▋         | 7/100 [00:16<02:35,  1.67s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   8%|▊         | 8/100 [00:17<02:09,  1.41s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#   9%|▉         | 9/100 [00:18<01:52,  1.23s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  10%|█         | 10/100 [00:19<01:40,  1.12s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  11%|█         | 11/100 [00:20<01:32,  1.04s/it]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  12%|█▏        | 12/100 [00:21<01:26,  1.02it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  13%|█▎        | 13/100 [00:22<01:21,  1.07it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  14%|█▍        | 14/100 [00:22<01:18,  1.10it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  15%|█▌        | 15/100 [00:23<01:15,  1.12it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  16%|█▌        | 16/100 [00:24<01:14,  1.13it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  17%|█▋        | 17/100 [00:25<01:12,  1.15it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  18%|█▊        | 18/100 [00:26<01:10,  1.16it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  19%|█▉        | 19/100 [00:27<01:09,  1.17it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  20%|██        | 20/100 [00:27<01:08,  1.17it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  21%|██        | 21/100 [00:28<01:07,  1.17it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  22%|██▏       | 22/100 [00:29<01:06,  1.17it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  23%|██▎       | 23/100 [00:30<01:05,  1.18it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  24%|██▍       | 24/100 [00:31<01:04,  1.18it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#
  1.11it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  89%|████████▉ | 89/100 [01:28<00:09,  1.11it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  90%|█████████ | 90/100 [01:29<00:09,  1.11it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  91%|█████████ | 91/100 [01:30<00:08,  1.12it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  92%|█████████▏| 92/100 [01:31<00:07,  1.12it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  93%|█████████▎| 93/100 [01:32<00:06,  1.13it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  94%|█████████▍| 94/100 [01:33<00:05,  1.13it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  95%|█████████▌| 95/100 [01:34<00:04,  1.13it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  96%|█████████▌| 96/100 [01:34<00:03,  1.14it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  97%|█████████▋| 97/100 [01:35<00:02,  1.13it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  98%|█████████▊| 98/100 [01:36<00:01,  1.12it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
#  99%|█████████▉| 99/100 [01:37<00:00,  1.12it/s]WARNING    Came across an abstract code block that may not be well-defined: the outcome may depend on the order of execution. You can ignore this warning if you are sure that the order of operations does not matter. 2 lines of abstract code, first line is: 'is_active = True'
#  [brian2.codegen.generators.base]
# 100%|██████████| 100/100 [01:38<00:00,  1.02it/s]

# %%
fig, ax = plt.subplots(3, 1, figsize = (6, 12), sharex = True)

print(spike_times)

plot_raster(np.array([spike_times/ms]), T, ax = ax[0])
ax[0].set_title("Pre- spike train")

plot_raster(np.array([spk_trn/ms]), T, ax = ax[1])
ax[1].set_title("Poisson spike train")

ax[2].plot(mon_post.t/ms, mon_post.v[0])
ax[2].set_title("Post- membrane potential")
ax[2].set_xlabel("Time [ms]")
ax[2].set_ylabel("v [mV]")
# Out:
# [0.01       0.04820513 0.08641026 0.12461538 0.16282051 0.20102564
#  0.23923077 0.2774359  0.31564103 0.35384615 0.39205128 0.43025641
#  0.46846154 0.50666667 0.54487179 0.58307692 0.62128205 0.65948718
#  0.69769231 0.73589744 0.77410256 0.81230769 0.85051282 0.88871795
#  0.92692308 0.96512821 1.00333333 1.04153846 1.07974359 1.11794872
#  1.15615385 1.19435897 1.2325641  1.27076923 1.30897436 1.34717949
#  1.38538462 1.42358974 1.46179487 1.5       ] s
# [  10.           48.20512821   86.41025641  124.61538462  162.82051282
#   201.02564103  239.23076923  277.43589744  315.64102564  353.84615385
#   392.05128205  430.25641026  468.46153846  506.66666667  544.87179487
#   583.07692308  621.28205128  659.48717949  697.69230769  735.8974359
#   774.1025641   812.30769231  850.51282051  888.71794872  926.92307692
#   965.12820513 1003.33333333 1041.53846154 1079.74358974 1117.94871795
#  1156.15384615 1194.35897436 1232.56410256 1270.76923077 1308.97435897
#  1347.17948718 1385.38461538 1423.58974359 1461.79487179 1500.        ]
# [  14.8   53.7   90.8  129.9  166.9  207.2  242.6  282.6  321.8  359.8
#   396.2  435.3  473.6  513.5  549.4  588.1  625.9  663.2  701.3  738.4
#   779.7  817.4  857.1  896.   931.4  970.1 1009.9 1046.  1084.7 1122.8
#  1160.2 1199.8 1240.3 1277.4 1314.9 1350.6 1389.3 1429.4 1467.9 1506.2]
# Text(0, 0.5, 'v [mV]')

# %%
# Visualization of the frequency transformation
print(f"DEFAULT DT: {defaultclock.dt*ms}")


avg_poiss = np.mean(counts)
std_poiss = np.std(counts)
print(f"Mean: {avg_poiss}")
print(f"STD: {std_poiss}")
print(f"Mean Ratio = {avg_poiss/N_spikes}")
print(f"STD Ratio = {std_poiss/N_spikes}")
# Out:
# DEFAULT DT: 0.1 ms^2
# Mean: 40.0
# STD: 0.0
# Mean Ratio = 1.0
# STD Ratio = 0.0

# %%
plt.hist(spike_delays, bins = 50)
plt.xlabel("Counts")
plt.ylabel("Time delay of synapse [ms]")
# Out:
# Text(0, 0.5, 'Time delay of synapse [ms]')

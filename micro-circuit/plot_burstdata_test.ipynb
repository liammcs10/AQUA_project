# %%
import numpy as np
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce

# %%
filename = "burst_analysis_test.pickle"

with open(filename, 'rb') as file:
    df = pickle.load(file)

print(df.head())
print("-------------------------")
print(df.iloc[-5:])
# Out:
#    sim_number neuron_label    e          f  tau  I_inj   W  FT_distance  \
# 0           0           E1  0.2   0.000000  2.0    200  56     1.976340
# 1           0           E2  0.2   0.000000  2.0    200  56     1.976340
# 2           1           E1  0.2  10.000000  2.0    200  56     1.937786
# 3           1           E2  0.2  10.000000  2.0    200  56     1.937786
# 4           2           E1  0.2  14.444444  2.0    200  56     1.978821
#
#       FT_EMD  SPIKE_distance  SPIKE_synchrony  spike_directionality  peak_isi  \
# 0  36.680473        0.086583              1.0             -0.987179     63.75
# 1  36.680473        0.086583              1.0             -0.987179     63.75
# 2  43.756253        0.087641              1.0             -0.987179     63.75
# 3  43.756253        0.087641              1.0             -0.987179     63.75
# 4  26.844168        0.087935              1.0             -0.987179     63.75
#
# ...

# %%
"""
Simulate and plot the phase response curve for an arbitrary neuron.

Push neuron into a steady state regime (Need to know the steady-state period before hand.)


Or know before hand the spike times and place the perturbation appropriately??

Create a batch of many neurons, each injected current will be the same baseline step current, 
with a different perturbation applied around the 10th ISI or so.

Need to vary the time of the perturbation, the amplitude, the duration, waveform?.
Keep track of factors like the net injected current due to the perturbation, onset time, 
or mean time of perturbation.

These are all aimed at understanding how the autapse might affect the base model neuron.

"""

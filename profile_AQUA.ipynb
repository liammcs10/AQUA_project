# %% [markdown]
# ### A few tests to systematically profile and optimise the AQUA and batchAQUA classes
#
# #### Section 1: Optimizing AQUA
#
# This short be a fairly short section aimed at optimizing the single neuron AQUA model
#
# #### Section 2: Optimizing batchAQUA
#
# This is a more complicated version attempting to optimise the vectorization of many AQUA neurons.
#
# #### Section 3: When to use which?
#
# This section will try to assess when to loop over several single neurons or to make a batch.

# %%
import numpy as np
from AQUA_general import AQUA
from batchAQUA_general import batchAQUA
import matplotlib.pyplot as plt

# %%
## representative example of a simulation would be found in 'general_model_testing.ipynb'

# run a simulation of a single neuron and a homo(hetero?)geneous batch of neurons, initialised halfway
# through the previous trial, previous autapse values input. 

# This would exploit the full functionality of the classes at the moment.
